# %%
pip install yfinance pandas pandas_datareader datetime numpy matplotlib
# Out:
# Requirement already satisfied: yfinance in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (0.2.54)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: pandas_datareader in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (0.10.0)
# Requirement already satisfied: datetime in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (5.5)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: requests>=2.31 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: lxml in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pandas_datareader) (5.3.1)
# Requirement already satisfied: zope.interface in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from datetime) (7.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from zope.interface->datetime) (76.0.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
from pandas_datareader import data as pdr
import datetime as dt
import numpy as np
import matplotlib
print("Imported Succesfully!!!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 6
#       4 import datetime as dt
#       5 import numpy as np
# ----> 6 import matplotlib
#       7 print("Imported Succesfully!!!")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
endDate = dt.datetime.now()

startDate = endDate - dt.timedelta(days = 365*5)
endDate, startDate
# Out:
# (datetime.datetime(2025, 3, 24, 12, 34, 1, 677572),
#  datetime.datetime(2020, 3, 25, 12, 34, 1, 677572))

# %%
stocks = ['MSFT', 'SPY', 'QQQ']

# %%
df = yf.download(stocks, start = startDate, end = endDate, auto_adjust=False, actions=True)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df.head()
# Out:
# Price        Adj Close                         Capital Gains            Close  \
# Ticker            MSFT         QQQ         SPY           QQQ  SPY        MSFT
# Date
# 2020-03-25  140.628647  177.176468  229.460220           0.0  0.0  146.919998
# 2020-03-26  149.425186  186.506622  242.858337           0.0  0.0  156.110001
# 2020-03-27  143.289627  180.092133  235.624634           0.0  0.0  149.699997
# 2020-03-30  153.368713  186.642654  243.276749           0.0  0.0  160.229996
# 2020-03-31  150.956665  185.048767  239.650574           0.0  0.0  157.710007
#
# Price                              Dividends       ...         Low  \
# Ticker             QQQ         SPY      MSFT  QQQ  ...         SPY
# Date                                               ...
# 2020-03-25  182.300003  246.789993       0.0  0.0  ...  239.750000
# 2020-03-26  191.899994  261.200012       0.0  0.0  ...  249.050003
# 2020-03-27  185.300003  253.419998       0.0  0.0  ...  251.050003
# 2020-03-30  192.039993  261.649994       0.0  0.0  ...  253.529999
# 2020-03-31  190.399994  257.750000       0.0  0.0  ...  256.220001
#
# Price             Open                         Stock Splits            \
# Ticker            MSFT         QQQ         SPY         MSFT  QQQ  SPY
# Date
# 2020-03-25  148.910004  184.419998  244.869995          0.0  0.0  0.0
# 2020-03-26  148.399994  183.869995  249.520004          0.0  0.0  0.0
# 2020-03-27  151.750000  186.929993  253.270004          0.0  0.0  0.0
# 2020-03-30  152.440002  187.059998  255.699997          0.0  0.0  0.0
# 2020-03-31  159.399994  191.720001  260.559998          0.0  0.0  0.0
#
# Price         Volume
# Ticker          MSFT       QQQ        SPY
# Date
# 2020-03-25  75638200  88754900  299430300
# 2020-03-26  64568100  79887600  257632800
# 2020-03-27  57042300  58845000  224341200
# 2020-03-30  63420300  49356900  171369500
# 2020-03-31  77927200  62659300  194881100
#
# [5 rows x 26 columns]

# %%
adj_closed_prices = df['Adj Close']

# %%
adj_closed_prices.head()
# Out:
# Ticker            MSFT         QQQ         SPY
# Date
# 2020-03-25  140.628647  177.176468  229.460220
# 2020-03-26  149.425186  186.506622  242.858337
# 2020-03-27  143.289627  180.092133  235.624634
# 2020-03-30  153.368713  186.642654  243.276749
# 2020-03-31  150.956665  185.048767  239.650574

# %%
log_returns = np.log(adj_closed_prices/adj_closed_prices.shift(1))
log_returns.head()
# Out:
# Ticker          MSFT       QQQ       SPY
# Date
# 2020-03-25       NaN       NaN       NaN
# 2020-03-26  0.060673  0.051321  0.056749
# 2020-03-27 -0.041928 -0.034998 -0.030238
# 2020-03-30  0.067977  0.035727  0.031960
# 2020-03-31 -0.015852 -0.008576 -0.015018

# %%
cumulative_log_returns = log_returns.cumsum()
cumulative_log_returns.head()
# Out:
# Ticker          MSFT       QQQ       SPY
# Date
# 2020-03-25       NaN       NaN       NaN
# 2020-03-26  0.060673  0.051321  0.056749
# 2020-03-27  0.018745  0.016322  0.026510
# 2020-03-30  0.086722  0.052050  0.058470
# 2020-03-31  0.070870  0.043473  0.043452

# %%
cumulative_log_returns.plot(title = "Cumulative Returns", figsize = (10,6))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cumulative_log_returns.plot(title = "Cumulative Returns", figsize = (10,6))
#
# File /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages/pandas/plotting/_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# File /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages/pandas/plotting/_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages/pandas/plotting/_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
